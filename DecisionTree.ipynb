# %%
import urllib.request as urllib2
import numpy as np
import matplotlib.pyplot as plt
### download data from UCI
x_train = 'https://archive.ics.uci.edu/ml/machine-learning-databases/madelon/MADELON/madelon_train.data'
x_test = 'https://archive.ics.uci.edu/ml/machine-learning-databases/madelon/MADELON/madelon_valid.data'
y_train = 'https://archive.ics.uci.edu/ml/machine-learning-databases/madelon/MADELON/madelon_train.labels'
y_test = 'https://archive.ics.uci.edu/ml/machine-learning-databases/madelon/madelon_valid.labels'
x_train = np.loadtxt(urllib2.urlopen(x_train))
y_train = np.loadtxt(urllib2.urlopen(y_train))
x_test = np.loadtxt(urllib2.urlopen(x_test))
y_test = np.loadtxt(urllib2.urlopen(y_test))

type(y_train)
# Out:
# numpy.ndarray

# %%
### Decision Tree Algorithm
from sklearn import tree
maximum_depth = list(range(1, 13))
e1=[]
e2=[]
for d in maximum_depth:
    clf = tree.DecisionTreeClassifier(max_depth = d, random_state = 0)
    clf.fit(x_train, y_train)
    score=clf.score(X_train,Y_train)
    print(score)
    tree.plot_tree(clf)
# Out:
# []
# []
# 0.6225
# 0.651
# 0.7165
# 0.7925
# 0.859
# 0.911
# 0.947
# 0.965
# 0.9785
# 0.99
# 0.9955
# 0.998

# %%
### from sklearn.tree import DecisionTreeClassifier
max_depth_range = list(range(1, 13))
error = []
error2= []
for depth in max_depth_range:
    clf = DecisionTreeClassifier(max_depth = depth, random_state = 0)
    clf.fit(X_train, Y_train)
    score=clf.score(X_train,Y_train)
    score2 = clf.score(X_val, Y_val)
    error.append(1-score)
    error2.append(1-score2)
plt.plot(max_depth_range,error, color = 'red',linewidth = 3.0,linestyle = '-',label='train_data')
plt.plot(max_depth_range,error2, color = 'blue',linewidth = 3.0,linestyle = '--',label='volid_data')
plt.ylabel('Errors')
plt.xlabel('max_depth')
plt.legend(loc = 'best')
plt.show()
a1=np.array(error)
a2=np.array(error2)
print('tree_depth_train:',np.argmin(a1)+1)
print('minimum_error_train:',a1[np.argmin(a1)])
print('tree_depth_volid:',np.argmin(a2)+1)
print('minimum_error_volid:',np.min(a2))
# Out:
# 0.6225
# 0.6116666666666667
# [0.37749999999999995]
# [0.3883333333333333]
# 0.651
# 0.665
# [0.37749999999999995, 0.349]
# [0.3883333333333333, 0.33499999999999996]
# 0.7165
# 0.715
# [0.37749999999999995, 0.349, 0.2835]
# [0.3883333333333333, 0.33499999999999996, 0.28500000000000003]
# 0.7925
# 0.7483333333333333
# [0.37749999999999995, 0.349, 0.2835, 0.20750000000000002]
# [0.3883333333333333, 0.33499999999999996, 0.28500000000000003, 0.2516666666666667]
# 0.859
# 0.795
# [0.37749999999999995, 0.349, 0.2835, 0.20750000000000002, 0.14100000000000001]
# [0.3883333333333333, 0.33499999999999996, 0.28500000000000003, 0.2516666666666667, 0.20499999999999996]
# 0.911
# 0.795
# [0.37749999999999995, 0.349, 0.2835, 0.20750000000000002, 0.14100000000000001, 0.08899999999999997]
# [0.3883333333333333, 0.33499999999999996, 0.28500000000000003, 0.2516666666666667, 0.20499999999999996, 0.20499999999999996]
# 0.947
# 0.785
# ...

# %%
 from sklearn import tree
    
 X = [[0, 0], [1, 1]]
 Y = [0, 1]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, Y)
print(clf)
score=clf.score(X,Y)
score
# Out:
# DecisionTreeClassifier()
# 1.0

# %%
a=5
b=1.55
print(a//b)
# Out:
# 3.0
